# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfanazhari1/kecerdasan-buatan/blob/main/image_fundamental/rotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/s/u27qgwztqb8b5ka/Kucing.jpg --no-check-certificate
# Out:
# --2021-11-10 06:21:13--  https://www.dropbox.com/s/u27qgwztqb8b5ka/Kucing.jpg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u27qgwztqb8b5ka/Kucing.jpg [following]
# --2021-11-10 06:21:13--  https://www.dropbox.com/s/raw/u27qgwztqb8b5ka/Kucing.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc52e46479e410c55abe30695695.dl.dropboxusercontent.com/cd/0/inline/BZseZN0zAdwpbyCWk4B46jv5FEFTk8w0ggFMk8tmnv5VhpV-naugzG1j-mnqeYDSnnV4yviqLko8uP0TZPVitKD4WwlZOwNlaiEOLWke0VENqn3tudjSQoVHIiOuZe-Opdu8wrX-JSrLkReS_6zyFUvf/file# [following]
# --2021-11-10 06:21:13--  https://uc52e46479e410c55abe30695695.dl.dropboxusercontent.com/cd/0/inline/BZseZN0zAdwpbyCWk4B46jv5FEFTk8w0ggFMk8tmnv5VhpV-naugzG1j-mnqeYDSnnV4yviqLko8uP0TZPVitKD4WwlZOwNlaiEOLWke0VENqn3tudjSQoVHIiOuZe-Opdu8wrX-JSrLkReS_6zyFUvf/file
# Resolving uc52e46479e410c55abe30695695.dl.dropboxusercontent.com (uc52e46479e410c55abe30695695.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601d:15::a27d:50f
# Connecting to uc52e46479e410c55abe30695695.dl.dropboxusercontent.com (uc52e46479e410c55abe30695695.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330902 (323K) [image/jpeg]
# Saving to: ‘Kucing.jpg’
#
# Kucing.jpg          100%[===================>] 323.15K  --.-KB/s    in 0.08s
#
# 2021-11-10 06:21:13 (3.86 MB/s) - ‘Kucing.jpg’ saved [330902/330902]

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import imutils
import cv2

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
args = {
    "image": "Kucing.jpg"
}

# %%
# load the image and show it
image = cv2.imread(args["image"])
plt_imshow("Original", image)

# grab the dimensions of the image and calculate the center of the
# image
(h, w) = image.shape[:2]
(cX, cY) = (w // 2, h // 2)

# rotate our image by 45 degrees around the center of the image
M = cv2.getRotationMatrix2D((cX, cY), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by 45 Degrees", rotated)

# rotate our image by -90 degrees around the image
M = cv2.getRotationMatrix2D((cX, cY), -90, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by -90 Degrees", rotated)

# %%
# rotate our image around an arbitrary point rather than the center
M = cv2.getRotationMatrix2D((10, 10), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by Arbitrary Point", rotated)

# %%
# use our imutils function to rotate an image 180 degrees
rotated = imutils.rotate(image, 180)
plt_imshow("Rotated by 180 Degrees", rotated)

# %%
# rotate our image by 33 degrees counterclockwise, ensuring the
# entire rotated image still views in the viewing area
rotated = imutils.rotate_bound(image, -33)
plt_imshow("Rotated Without Cropping", rotated)
