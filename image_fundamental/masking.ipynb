# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfanazhari1/kecerdasan-buatan/blob/main/image_fundamental/masking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/s/2eyp8cjf4rl826a/Kucing.jpeg --no-check-certificate
# Out:
# --2021-11-10 06:50:47--  https://www.dropbox.com/s/2eyp8cjf4rl826a/Kucing.jpeg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/2eyp8cjf4rl826a/Kucing.jpeg [following]
# --2021-11-10 06:50:48--  https://www.dropbox.com/s/raw/2eyp8cjf4rl826a/Kucing.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com/cd/0/inline/BZt6FM321K7vbsKFkti5Fnaz97iuD12so9Vsl6tae9e3Rv6_maDs71k0brOeFdfH6y5M9NYvAj_rax1v-HCqhonPjZf97pz_B_g6dwfvry7iBwlvDVrLa9cG-ZRnH1GPO7W4tChx7jrr9txQHyA94XvL/file# [following]
# --2021-11-10 06:50:48--  https://uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com/cd/0/inline/BZt6FM321K7vbsKFkti5Fnaz97iuD12so9Vsl6tae9e3Rv6_maDs71k0brOeFdfH6y5M9NYvAj_rax1v-HCqhonPjZf97pz_B_g6dwfvry7iBwlvDVrLa9cG-ZRnH1GPO7W4tChx7jrr9txQHyA94XvL/file
# Resolving uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com (uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com (uca8384b6586a90dbfae7b712d86.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3548863 (3.4M) [image/jpeg]
# Saving to: ‘Kucing.jpeg’
#
# Kucing.jpeg         100%[===================>]   3.38M  17.4MB/s    in 0.2s
#
# 2021-11-10 06:50:49 (17.4 MB/s) - ‘Kucing.jpeg’ saved [3548863/3548863]

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "Kucing.jpeg"
}

# %%
# load the original input image and display it to our screen
image = cv2.imread(args["image"])
plt_imshow("Original", image)

# a mask is the same size as our image, but has only two pixel
# values, 0 and 255 -- pixels with a value of 0 (background) are
# ignored in the original image while mask pixels with a value of
# 255 (foreground) are allowed to be kept
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (0, 90), (290, 450), 255, -1)
plt_imshow("Rectangular Mask", mask)

# apply our mask -- notice how only the person in the image is
# cropped out
masked = cv2.bitwise_and(image, image, mask=mask)
plt_imshow("Mask Applied to Image", masked)

# %%
# now, let's make a circular mask with a radius of 100 pixels and
# apply the mask again
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.circle(mask, (145, 200), 100, 255, -1)
masked = cv2.bitwise_and(image, image, mask=mask)

# show the output images
plt_imshow("Circular Mask", mask)
plt_imshow("Mask Applied to Image", masked)
