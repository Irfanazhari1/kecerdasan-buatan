# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfanazhari1/kecerdasan-buatan/blob/main/image_fundamental/flipping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/s/2eyp8cjf4rl826a/Kucing.jpeg --no-check-certificate
# Out:
# --2021-11-10 06:37:36--  https://www.dropbox.com/s/2eyp8cjf4rl826a/Kucing.jpeg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/2eyp8cjf4rl826a/Kucing.jpeg [following]
# --2021-11-10 06:37:36--  https://www.dropbox.com/s/raw/2eyp8cjf4rl826a/Kucing.jpeg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com/cd/0/inline/BZsu3I0cM-U5-nDi-p0dPOIpNnQW33j3beghQGrp9aMtGNcPXPTZ5QZ8k-uPfKchVNAo3g1VwKJ5kfTD0tcEX9PQvxPTgJuoJuFxufZ3RHcbSwd5nASiM_eaoz-lW06oHEX85SgO2yaprUMw9myjJg-n/file# [following]
# --2021-11-10 06:37:36--  https://ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com/cd/0/inline/BZsu3I0cM-U5-nDi-p0dPOIpNnQW33j3beghQGrp9aMtGNcPXPTZ5QZ8k-uPfKchVNAo3g1VwKJ5kfTD0tcEX9PQvxPTgJuoJuFxufZ3RHcbSwd5nASiM_eaoz-lW06oHEX85SgO2yaprUMw9myjJg-n/file
# Resolving ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com (ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6017:15::a27d:20f
# Connecting to ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com (ucc9093e9b864e3b5e26e5aaa63c.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3548863 (3.4M) [image/jpeg]
# Saving to: ‘Kucing.jpeg’
#
# Kucing.jpeg         100%[===================>]   3.38M  9.19MB/s    in 0.4s
#
# 2021-11-10 06:37:37 (9.19 MB/s) - ‘Kucing.jpeg’ saved [3548863/3548863]

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# # construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-i", "--image", type=str, default="office.jfif",
# 	help="path to the input image")
# args = vars(ap.parse_args())

# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "Kucing.jpeg"
}

# %%
# load the original input image and display it to our screen
image = cv2.imread(args["image"])
plt_imshow("Original", image)

# flip the image horizontally
print("[INFO] flipping image horizontally...")
flipped = cv2.flip(image, 1)
plt_imshow("Flipped Horizontally", flipped)
# Out:
# [INFO] flipping image horizontally...

# %%
# flip the image vertically
flipped = cv2.flip(image, 0)
print("[INFO] flipping image vertically...")
plt_imshow("Flipped Vertically", flipped)
# Out:
# [INFO] flipping image vertically...

# %%
# flip the image along both axes
flipped = cv2.flip(image, -1)
print("[INFO] flipping image horizontally and vertically...")
plt_imshow("Flipped Horizontally & Vertically", flipped)
# Out:
# [INFO] flipping image horizontally and vertically...
